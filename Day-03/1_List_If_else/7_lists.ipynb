# %%
items = ["breads", "pasta", "fruits", "veggies"]

# %%
items
# Out:
# ['breads', 'pasta', 'fruits', 'veggies']

# %%
items[:2]
# Out:
# ['breads', 'pasta']

# %%
items.append('butter')
items
# Out:
# ['breads', 'pasta', 'fruits', 'veggies', 'butter']

# %%
items.remove('butter')

# %%
items
# Out:
# ['breads', 'pasta', 'fruits', 'veggies']

# %%
items.insert(1,"butter")

# %%
items
# Out:
# ['breads', 'butter', 'pasta', 'fruits', 'veggies']

# %%
items[1] = 'cheese'
items
# Out:
# ['breads', 'cheese', 'pasta', 'fruits', 'veggies']

# %%
items[3:] = ["almonds"]
items
# Out:
# ['breads', 'cheese', 'pasta', 'almonds']

# %%
'rice' in items
# Out:
# False

# %%
'breads' in items
# Out:
# True

# %%
expenses = [30,1200,45,300]
expenses.sort(reverse = True)
expenses
# Out:
# [1200, 300, 45, 30]

# %%
food_items = ["bread", "pasta", "fruits"]
bathroom_items = ["shampoo", "soap"]

# %%
items = food_items + bathroom_items

# %%
items
# Out:
# ['bread', 'pasta', 'fruits', 'shampoo', 'soap']

# %%
len(items)
# Out:
# 5

# %%
items.pop(1)
# Out:
# 'pasta'

# %%
items
# Out:
# ['bread', 'fruits', 'shampoo', 'soap']

# %%
items.reverse()
items
# Out:
# ['soap', 'shampoo', 'fruits', 'bread']
